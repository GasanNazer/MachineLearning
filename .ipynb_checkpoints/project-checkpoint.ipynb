# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import scipy
from PIL import Image
from scipy import ndimage

# %matplotlib inline

# %%
# GRADED FUNCTION: image2vector
def image2vector(image):
    """
    Argument:
    image -- a numpy array of shape (length, height, depth)
    
    Returns:
    v -- a vector of shape (length*height*depth, 1)
    """
    
    ### START CODE HERE ### (≈ 1 line of code)
    v = image.reshape(image.shape[0]*image.shape[1]*image.shape[2], 1)
    ### END CODE HERE ###
    
    return v

# %%
# This is a 3 by 3 by 2 array, typically images will be (num_px_x, num_px_y,3) where 3 represents the RGB values
image = np.array([[[ 0.67826139,  0.29380381],
        [ 0.90714982,  0.52835647],
        [ 0.4215251 ,  0.45017551]],

       [[ 0.92814219,  0.96677647],
        [ 0.85304703,  0.52351845],
        [ 0.19981397,  0.27417313]],

       [[ 0.60659855,  0.00533165],
        [ 0.10820313,  0.49978937],
        [ 0.34144279,  0.94630077]]])

print ("image2vector(image) = " + str(image2vector(image)))
# Out:
# image2vector(image) = [[0.67826139]
#  [0.29380381]
#  [0.90714982]
#  [0.52835647]
#  [0.4215251 ]
#  [0.45017551]
#  [0.92814219]
#  [0.96677647]
#  [0.85304703]
#  [0.52351845]
#  [0.19981397]
#  [0.27417313]
#  [0.60659855]
#  [0.00533165]
#  [0.10820313]
#  [0.49978937]
#  [0.34144279]
#  [0.94630077]]

# %%
import imageio
from PIL import Image

## START CODE HERE ## (PUT YOUR IMAGE NAME) 
my_image = "1.jpeg"   # change this to the name of your image file 
## END CODE HERE ##

images = []

# We preprocess the image to fit your algorithm.
fname = "images/" + my_image
image_loaded = np.array(imageio.imread(fname))

num_px = 64

my_image = Image.fromarray(image_loaded).resize(size=(num_px, num_px))
my_image_array = np.array(my_image)
plt.imshow(my_image)
my_image_array_normalized = my_image_array/255.
my_image_array_normalized = np.reshape(my_image_array_normalized, (1, num_px*num_px*3)).T
print(my_image_array_normalized.shape)
print(my_image_array_normalized)
#my_predicted_image = predict(d["w"], d["b"], my_image)

plt.imshow(image)

### delete it loading second image
images.append(my_image_array_normalized)
my_image = "2.jpeg" 
# We preprocess the image to fit your algorithm.
fname = "images/" + my_image
image_loaded = np.array(imageio.imread(fname))

num_px = 64

my_image = Image.fromarray(image_loaded).resize(size=(num_px, num_px))
my_image_array = np.array(my_image)
plt.imshow(my_image)
my_image_array_normalized = my_image_array/255.
my_image_array_normalized = np.reshape(my_image_array_normalized, (1, num_px*num_px*3)).T
print(my_image_array_normalized.shape)
print(my_image_array_normalized)
#my_predicted_image = predict(d["w"], d["b"], my_image)

plt.imshow(image)

### delete it

images.append(my_image_array_normalized)

print(np.array(images).shape)
res = np.array(images).reshape((2, num_px*num_px*3)) # apending all images and reshaping the vector should be generalized
print(res.shape)
print(res)

#print("y = " + str(np.squeeze(my_predicted_image)) + ", your algorithm predicts a \"" + classes[int(np.squeeze(my_predicted_image)),].decode("utf-8") +  "\" picture.")
# Out:
# (12288, 1)
# [[0.89803922]
#  [0.89803922]
#  [0.85882353]
#  ...
#  [0.95294118]
#  [0.93333333]
#  [0.90980392]]
# (12288, 1)
# [[0.37647059]
#  [0.19215686]
#  [0.3254902 ]
#  ...
#  [0.26666667]
#  [0.23921569]
#  [0.32941176]]
# (2, 12288, 1)
# (2, 12288)
# [[0.89803922 0.89803922 0.85882353 ... 0.95294118 0.93333333 0.90980392]
#  [0.37647059 0.19215686 0.3254902  ... 0.26666667 0.23921569 0.32941176]]
